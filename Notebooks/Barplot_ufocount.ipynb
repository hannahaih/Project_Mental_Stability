# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yearly = pd.read_csv('../Data/Datasets/yearly_ufopct_entrtm.csv')

# %%
#barplot number of UFO sightings over time
fig, ax = plt.subplots(figsize = (20, 10))

plt.rcParams.update({'font.size': 18})

ax1 = sns.barplot(yearly.year_id , yearly.yearly_ufocount, color = 'darkturquoise')

ax.set_title( 'UFO‘s over time\n' )

ax1.set_xlabel ('')
ax1.set_ylabel ('Number of UFO‘s\n')

#plt.savefig("../BeautifulPlots/ufocount_barplotv1.png")
# Out:
# Text(0, 0.5, 'Number of UFO‘s\n')
