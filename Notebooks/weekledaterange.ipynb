# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from numpy import arange
import math

import seaborn as sns
sns.set_style("white")

import scipy as sp
from scipy import linalg, optimize

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

import collections
from collections import Counter

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.dates import DateFormatter

import calendar
import datetime as dt
fromtimestamp = dt.datetime.fromtimestamp

# %%
df = pd.read_csv('../Data/Raw/ufo_raw.csv')

# %%
df.head(1)
# Out:
#               datetime                           City State      Shape  \
# 0  2006-01-01 01:20:00  I-80 (unknown city proximity)    NY  Formation
#
#                     Duration  \
# 0  0 days 00:00:20.000000000
#
#                                              Summary  Posted Unnamed: 7  \
# 0  Traveling from Brooklyn, NY to Groton, NY on I...  6/7/19        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN         NaN

# %%
wdf = df.copy()
wdf.columns
# Out:
# Index(['datetime', 'City', 'State', 'Shape', 'Duration', 'Summary', 'Posted',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
wdf['datetype'] = pd.to_datetime(wdf['datetime']).dt.date
wdf.head()
# Out:
#               datetime                           City State      Shape  \
# 0  2006-01-01 01:20:00  I-80 (unknown city proximity)    NY  Formation
# 1  2006-01-01 23:00:00   San Antonio/Laredo (between)    TX   Triangle
# 2  2006-01-02 00:00:00                      Ann Arbor    MI   Changing
# 3  2006-01-02 00:00:00                 Fredericksburg    VA      Light
# 4  2006-01-04 07:45:00                       Scotland    PA      Light
#
#                     Duration  \
# 0  0 days 00:00:20.000000000
# 1  0 days 00:03:00.000000000
# 2  0 days 00:03:00.000000000
# 3  0 days 00:02:00.000000000
# 4  0 days 00:01:00.000000000
#
#                                              Summary    Posted Unnamed: 7  \
# 0  Traveling from Brooklyn, NY to Groton, NY on I...    6/7/19        NaN
# 1  Three separate sightins which ocurred in rural...    6/9/09        NaN
# 2  Probable HOAX: 5 ufos, silent black objects, m...  10/30/06        NaN
# 3  clear sky looked like a star 10:00 am in the m...    2/1/07        NaN
# 4  Small, white, light in the northeast sky...dis...    2/1/07        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10    datetype
# 0        NaN        NaN         NaN  2006-01-01
# 1        NaN        NaN         NaN  2006-01-01
# 2        NaN        NaN         NaN  2006-01-02
# 3        NaN        NaN         NaN  2006-01-02
# 4        NaN        NaN         NaN  2006-01-04

# %%
wdf['dttyp'] = pd.to_datetime(wdf['datetype'])

# %%
wdf['weeknum'] = wdf['dttyp'].dt.week
# Out:
# <ipython-input-147-b9d7638e36fd>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   wdf['weeknum'] = wdf['dttyp'].dt.week

# %%
wdf['weekofyear'] = wdf['dttyp'].dt.weekofyear
# Out:
# <ipython-input-148-6f1049e9a1ef>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   wdf['weekofyear'] = wdf['dttyp'].dt.weekofyear

# %%
wdf['year'] = wdf['dttyp'].dt.year

# %%
wdf['year_week'] = wdf['year'].astype(str) + "-" + wdf['weekofyear'].astype(str)

# %%
wdf = wdf.drop(columns=['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'datetype'])

# %%
wdf = wdf.drop(columns=['datetime','weeknum'])

# %%
wdf.head()
# Out:
#                             City State      Shape                   Duration  \
# 0  I-80 (unknown city proximity)    NY  Formation  0 days 00:00:20.000000000
# 1   San Antonio/Laredo (between)    TX   Triangle  0 days 00:03:00.000000000
# 2                      Ann Arbor    MI   Changing  0 days 00:03:00.000000000
# 3                 Fredericksburg    VA      Light  0 days 00:02:00.000000000
# 4                       Scotland    PA      Light  0 days 00:01:00.000000000
#
#                                              Summary    Posted      dttyp  \
# 0  Traveling from Brooklyn, NY to Groton, NY on I...    6/7/19 2006-01-01
# 1  Three separate sightins which ocurred in rural...    6/9/09 2006-01-01
# 2  Probable HOAX: 5 ufos, silent black objects, m...  10/30/06 2006-01-02
# 3  clear sky looked like a star 10:00 am in the m...    2/1/07 2006-01-02
# 4  Small, white, light in the northeast sky...dis...    2/1/07 2006-01-04
#
#    weekofyear  year year_week
# 0          52  2006   2006-52
# 1          52  2006   2006-52
# 2           1  2006    2006-1
# 3           1  2006    2006-1
# 4           1  2006    2006-1

# %%
wdf['dttyp'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
ufodata = pd.DataFrame(wdf['year_week'])

# %%
ufodata['date_of_sight'] = wdf['dttyp']

# %%
ufodata['year'] = wdf['year']
ufodata['month'] = wdf['dttyp'].dt.month
ufodata['week_of_year'] = wdf['weekofyear']
ufodata['state'] = wdf['State']
ufodata['city'] = wdf['City']
ufodata['sight_summary'] = wdf['Summary']

# %%
ufodata['ufo_shape'] = wdf['Shape']

# %%
ufodata = ufodata.reset_index()

# %%
dt = pd.date_range("20060102","20200906", freq='W')
datedf = pd.DataFrame(dt).rename(columns={0:'startdayweek'})

datedf['weeknum'] = datedf['startdayweek'].dt.isocalendar().week
datedf['month'] = datedf['startdayweek'].dt.month
datedf['year'] = datedf['startdayweek'].dt.year
datedf['week_id'] = datedf['year'].astype(str)+"-"+datedf['weeknum'].astype(str)

# %%
ufocount = ufodata.copy().drop(columns=['index','state','city','sight_summary','ufo_shape']).rename(columns={'year_week':'week_id'} ).sort_values('week_id').reset_index()
ufocount.head(1)
# Out:
#    index week_id date_of_sight  year  month  week_of_year
# 0      2  2006-1    2006-01-02  2006      1             1

# %%
datedf.head(1)
# Out:
#   startdayweek  weeknum  month  year week_id
# 0   2006-01-08        1      1  2006  2006-1

# %%
ufo_cleaned_fin = pd.merge(left=datedf, right=ufocount, left_on='week_id', right_on='week_id')

# %%
ufo_cleaned_fin
# Out:
#       startdayweek  weeknum  month_x  year_x  week_id  index date_of_sight  \
# 0       2006-01-08        1        1    2006   2006-1      2    2006-01-02
# 1       2006-01-08        1        1    2006   2006-1      3    2006-01-02
# 2       2006-01-08        1        1    2006   2006-1      4    2006-01-04
# 3       2006-01-15        2        1    2006   2006-2      5    2006-01-12
# 4       2006-01-15        2        1    2006   2006-2      6    2006-01-12
# ...            ...      ...      ...     ...      ...    ...           ...
# 71616   2020-09-06       36        9    2020  2020-36  70922    2020-08-31
# 71617   2020-09-06       36        9    2020  2020-36  70923    2020-08-31
# 71618   2020-09-06       36        9    2020  2020-36  70920    2020-08-31
# 71619   2020-09-06       36        9    2020  2020-36  70925    2020-08-31
# 71620   2020-09-06       36        9    2020  2020-36  70926    2020-08-31
#
#        year_y  month_y  week_of_year
# 0        2006        1             1
# 1        2006        1             1
# 2        2006        1             1
# 3        2006        1             2
# 4        2006        1             2
# ...       ...      ...           ...
# 71616    2020        8            36
# 71617    2020        8            36
# 71618    2020        8            36
# 71619    2020        8            36
# 71620    2020        8            36
#
# [71621 rows x 10 columns]

# %%
wdfweek = ufo_cleaned_fin.copy().drop(columns=['weeknum','index','year_x','month_x'])
wdfweek.head()
# Out:
#   startdayweek week_id date_of_sight  year_y  month_y  week_of_year
# 0   2006-01-08  2006-1    2006-01-02    2006        1             1
# 1   2006-01-08  2006-1    2006-01-02    2006        1             1
# 2   2006-01-08  2006-1    2006-01-04    2006        1             1
# 3   2006-01-15  2006-2    2006-01-12    2006        1             2
# 4   2006-01-15  2006-2    2006-01-12    2006        1             2

# %%
# store counts per week_id in "ufosperweek" df
ufosperweek = pd.DataFrame(wdfweek['startdayweek'].value_counts()).reset_index().rename(columns={'index':'startdateweek','startdayweek': 'weekly_ufocount'})
# review
ufosperweek.head(1)
# Out:
#   startdateweek  weekly_ufocount
# 0    2014-07-06              470

# %%
maxalltime = ufosperweek.weekly_ufocount.max() 
onepct = maxalltime/100

# %%
ufosperweek['rel_val_alltime'] = ufosperweek['weekly_ufocount']/onepct

# %%
ufosperweek['year'] = ufosperweek['startdateweek'].dt.year
ufosperweek['month'] = ufosperweek['startdateweek'].dt.month
ufosperweek['weeknum'] = ufosperweek['startdateweek'].dt.isocalendar().week 
ufosperweek['week_id'] = ufosperweek['year'].astype(str) + "-" + ufosperweek['weeknum'].astype(str)

# %%
ufosperweek.head()
# Out:
#   startdateweek  weekly_ufocount  rel_val_alltime  year  month  weeknum  \
# 0    2014-07-06              470       100.000000  2014      7       27
# 1    2015-11-08              406        86.382979  2015     11       45
# 2    2020-04-19              403        85.744681  2020      4       16
# 3    2013-07-07              399        84.893617  2013      7       27
# 4    2012-07-08              339        72.127660  2012      7       27
#
#    week_id
# 0  2014-27
# 1  2015-45
# 2  2020-16
# 3  2013-27
# 4  2012-27

# %%
pd.to_csv('../Data/Datasets/cleandate_weekly_reval.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-ef8bcde22ff9> in <module>
# ----> 1 pd.to_csv('../Data/Datasets/cleandate_weekly_reval.csv')
#
# ~\anaconda3\envs\matrix\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'to_csv'
