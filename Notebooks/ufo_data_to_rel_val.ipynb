# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from numpy import arange
import math

import seaborn as sns
sns.set_style("white")

import scipy as sp
from scipy import linalg, optimize

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

import collections
from collections import Counter

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.path as mpath
from matplotlib.dates import DateFormatter

import calendar
import datetime as dt
fromtimestamp = dt.datetime.fromtimestamp

# %%
# import ufo data, assign ufo_id and sort
ufo = pd.read_csv('../data/ufo_clean.csv', index_col = 0)
ufo = ufo.rename(columns={'index':'ufo_id','year_week':'week_id'})
ufo['ufo_id'] = 1
ufo = ufo.sort_values('week_id')
# confirm
ufo.head()
# Out:
#     ufo_id  week_id date_of_sight  year  month  week_of_year state  \
# 2        1   2006-1    2006-01-02  2006      1             1    MI
# 3        1   2006-1    2006-01-02  2006      1             1    VA
# 4        1   2006-1    2006-01-04  2006      1             1    PA
# 53       1  2006-10    2006-03-06  2006      3            10    CA
# 54       1  2006-10    2006-03-07  2006      3            10    CA
#
#                   city                                      sight_summary  \
# 2            Ann Arbor  Probable HOAX: 5 ufos, silent black objects, m...
# 3       Fredericksburg  clear sky looked like a star 10:00 am in the m...
# 4             Scotland  Small, white, light in the northeast sky...dis...
# 53         North Hills  ((HOAX)) As I sat in my car taking my break, I...
# 54  Desert Hot Springs  Twin OrangeTriangles flying at extrememly high...
#
#    ufo_shape
# 2   Changing
# 3      Light
# 4      Light
# 53       Egg
# 54   Chevron

# %%
# store counts per week_id in "ufosperweek" df
ufosperweek = pd.DataFrame(ufo['date_of_sight'].value_counts()).reset_index().rename(columns={'index':'week_id','date_of_sight': 'date'})
# review
ufosperweek
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0560cc85b013> in <module>
#       1 # store counts per week_id in "ufosperweek" df
# ----> 2 ufosperweek = pd.DataFrame(ufo['date_of_sight'].value_counts()).reset_index().rename(columns={'index':'week_id','date_of_sight': 'date'})
#       3 # review
#       4 ufosperweek
#
# NameError: name 'pd' is not defined

# %%
# check dtypes
ufosperweek.dtypes
# Out:
# week_id            object
# weekly_ufocount     int64
# dtype: object

# %%
# get max ufo per week count and save it to ufomax
ufoweekmax = ufosperweek.weekly_ufocount.max()

# %%
# define 1 percent value: (ufoweekmax = 100 pct)
onepc_ufoweek = ufoweekmax/100

# %%
# update ufosperweek with percentage values
ufosperweek['weekly_pct_entrtm'] = ufosperweek['weekly_ufocount']/onepc_ufoweek
# review
ufosperweek.head()
# Out:
#    week_id  weekly_ufocount  weekly_pct_entrtm
# 0  2014-27              470         100.000000
# 1  2015-45              406          86.382979
# 2  2020-16              403          85.744681
# 3  2013-27              399          84.893617
# 4  2012-27              339          72.127660

# %%
# get ufo counts per year and save to "ufosperyear" df
ufosperyear = pd.DataFrame(ufo['year'].value_counts()).reset_index().rename(columns={'index':'year_id','year':'yearly_ufocount'})
# review
ufosperyear.head()
# Out:
#    year_id  yearly_ufocount
# 0     2014             7431
# 1     2012             6867
# 2     2013             6602
# 3     2015             5880
# 4     2016             4848

# %%
# get max ufo per week count and save it to ufomax
ufoyearmax = ufosperyear.yearly_ufocount.max()

# define 1 percent value: (ufoyearmax = 100 pct)
onepc_ufoyear = ufoyearmax/100

# assign col with percentage vals
ufosperyear['yearly_pct_entrtm'] = ufosperyear['yearly_ufocount']/onepc_ufoyear

# review
ufosperyear.head()
# Out:
#    year_id  yearly_ufocount  yearly_pct_entrtm
# 0     2014             7431         100.000000
# 1     2012             6867          92.410174
# 2     2013             6602          88.844032
# 3     2015             5880          79.127977
# 4     2016             4848          65.240210

# %%
    # export and set to comment after
#ufosperyear.to_csv('../Data/Datasets/yearly_ufopct_entrtm.csv')
#ufosperweek.to_csv('../Data/Datasets/weekly_ufopct_entrtm.csv')

# %%
plotdf = pd.DataFrame({'year':ufosperyear['year_id'], 'ufo year %':ufosperyear['yearly_pct_entrtm']})
plotdf
# Out:
#     year  ufo year %
# 0   2014  100.000000
# 1   2012   92.410174
# 2   2013   88.844032
# 3   2015   79.127977
# 4   2016   65.240210
# 5   2011   64.782667
# 6   2019   64.204010
# 7   2020   62.427668
# 8   2008   58.726955
# 9   2017   57.811869
# 10  2009   53.411385
# 11  2010   52.630871
# 12  2007   50.975643
# 13  2018   36.926389
# 14  2006   35.540304
